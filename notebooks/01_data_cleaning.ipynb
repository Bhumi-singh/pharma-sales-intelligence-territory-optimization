# %% [markdown]
# # 01 - Data Cleaning
#
# Load raw pharma sales data, inspect quality, clean, and save a processed CSV for downstream notebooks.

# %%
import sys
sys.path.append("../src")

import pandas as pd
from data_cleaning import run_pipeline, load_data, clean_column_names, check_data_quality, clean_data, save_processed

# %% [markdown]
# ## Option A: Run the full pipeline at once

# %%
df = run_pipeline(
    raw_path="../data/raw/Pharma_data_analysis.xlsx",
    processed_path="../data/processed/cleaned_data.csv",
    sheet_name="Pharma_data"  # update if your sheet name differs
)
df.head()

# %% [markdown]
# ## Option B: Run step-by-step (for inspection)

# %%
df = load_data("../data/raw/Pharma_data_analysis.xlsx", sheet_name="Pharma_data")
df.head()

# %%
df = clean_column_names(df)
df.columns.tolist()

# %%
check_data_quality(df)

# %%
df = clean_data(df)
df.head()

# %%
# Quick sanity checks
print(df['country'].unique())
print(df['sales_team'].unique())
print(df['year'].unique())
print(df['date'].min(), df['date'].max())

# %%
save_processed(df, "../data/processed/cleaned_data.csv")
